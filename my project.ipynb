# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Date Collecion

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# ## Show the columns name

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %% [markdown]
# ## converting first letter capital

# %%
df.columns=['Gender', 'Age', 'Hypertension', 'Heart_disease', 'Smoking_history',
       'Bmi', 'HbA1c_level', 'Blood_glucose_level', 'Diabetes']
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Hypertension', 'Heart_disease', 'Smoking_history',
#        'Bmi', 'HbA1c_level', 'Blood_glucose_level', 'Diabetes'],
#       dtype='object')

# %% [markdown]
# ## shape of the DataFrame

# %%
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# ## Display the first 10 rows of the DataFrame

# %%
df.head(10)
# Out:
#    Gender   Age  Hypertension  Heart_disease Smoking_history    Bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  Blood_glucose_level  Diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# ...

# %% [markdown]
# ## Display the last 10 rows of the DataFrame

# %%
df.tail(10)
# Out:
#        Gender   Age  Hypertension  Heart_disease Smoking_history    Bmi  \
# 99990    Male  39.0             0              0         No Info  27.32
# 99991    Male  22.0             0              0         current  29.65
# 99992  Female  26.0             0              0           never  34.34
# 99993  Female  40.0             0              0           never  40.69
# 99994  Female  36.0             0              0         No Info  24.60
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  Blood_glucose_level  Diabetes
# 99990          6.1                  100         0
# 99991          6.0                   80         0
# ...

# %% [markdown]
# ## Information about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Gender               100000 non-null  object
#  1   Age                  100000 non-null  float64
#  2   Hypertension         100000 non-null  int64
#  3   Heart_disease        100000 non-null  int64
#  4   Smoking_history      100000 non-null  object
#  5   Bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   Blood_glucose_level  100000 non-null  int64
#  8   Diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ## Obtain summary statistics

# %%
df.describe()
# Out:
#                  Age  Hypertension  Heart_disease            Bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  Blood_glucose_level       Diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# ## Find the mode of the DataFrame

# %%
df.mode()
# Out:
#    Gender   Age  Hypertension  Heart_disease Smoking_history    Bmi  \
# 0  Female  80.0             0              0         No Info  27.32
#
#    HbA1c_level  Blood_glucose_level  Diabetes
# 0          6.6                  130         0

# %% [markdown]
# ## Find the median of the DataFrame

# %%
df.median()
# Out:
# Age                     43.00
# Hypertension             0.00
# Heart_disease            0.00
# Bmi                     27.32
# HbA1c_level              5.80
# Blood_glucose_level    140.00
# Diabetes                 0.00
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing value

# %%
df.isnull().sum()
# Out:
# Gender                 0
# Age                    0
# Hypertension           0
# Heart_disease          0
# Smoking_history        0
# Bmi                    0
# HbA1c_level            0
# Blood_glucose_level    0
# Diabetes               0
# dtype: int64

# %% [markdown]
# ## Drop with missing value

# %%
df.dropna()
# Out:
#        Gender   Age  Hypertension  Heart_disease Smoking_history    Bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  Blood_glucose_level  Diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# ## Identify the Duplicates value

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995     True
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %% [markdown]
# ## Removing the Duplicates value

# %%
df.drop_duplicates()
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Remove duplicate rows in-place

# %%
df.drop_duplicates(inplace=True)
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## shape of the DataFrame after removing duplicates

# %%
df.shape
# Out:
# (96146, 9)

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Age'], bins=50, kde=True,color='Blue')
plt.xlabel('Age')
plt.ylabel('People')
plt.title('Histogram of Age Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Blood_glucose_level'], bins=18, kde=True,color='Blue')

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Bmi'], bins=25, kde=True,color='Blue')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['HbA1c_level'], bins=20, kde=True,color='Blue')
plt.show()

# %%
selected_columns = ['Gender', 'Hypertension', 'Smoking_history', 'Heart_disease', 'Diabetes']

for selected_column in selected_columns:
    counts = df[selected_column].value_counts()
    plt.figure(figsize=(6, 6))
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'Pie Chart of {selected_column}')
    plt.show()

# %%
sns.countplot(x = 'Gender', data = df, palette = 'magma')
plt.title("Gender_plot")
plt.show()

# %%
df["Heart_disease"].value_counts()
# Out:
# 0    92223
# 1     3923
# Name: Heart_disease, dtype: int64

# %%
labels = ['Yes', 'No']
custom_colors = ['green', 'red']
plt.pie(df.Heart_disease.value_counts(), labels=labels, autopct='%.1f%%',colors=custom_colors)
plt.title("Heart_disease")
plt.show()

# %%
df["Smoking_history"].value_counts()
# Out:
# never          34398
# No Info        32887
# former          9299
# current         9197
# not current     6367
# ever            3998
# Name: Smoking_history, dtype: int64

# %%
sns.barplot(x='Smoking_history',y='Age',data=df,palette='PuRd',errorbar=None)
plt.title("Smoking_History_level", fontsize=16)
plt.show()

# %%
df["Blood_glucose_level"].value_counts()
# Out:
# 159    7478
# 130    7471
# 126    7421
# 140    7416
# 160    7397
# 145    7371
# 200    7290
# 155    7285
# 90     6822
# 80     6786
# 100    6774
# 158    6739
# 85     6632
# 280     724
# 300     673
# 260     634
# 240     633
# 220     600
# Name: Blood_glucose_level, dtype: int64

# %%
custom_colors = ['cyan', 'blue', 'green', 'yellow', 'red']
df['Blood_glucose_level'].value_counts().plot(kind='barh', figsize=(12,4), color=custom_colors, fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Glucose_level", fontsize=12)
plt.title("Blood_glucose_level", fontsize=16)
plt.show()

# %%
sns.relplot(data=df,x="HbA1c_level",y="Age",kind="line",errorbar=None)
plt.show()

# %% [markdown]
# # Correlation

# %%
corr=df.corr()
corr
# Out:
#                           Age  Hypertension  Heart_disease       Bmi  \
# Age                  1.000000      0.257305       0.238451  0.344797
# Hypertension         0.257305      1.000000       0.119982  0.148111
# Heart_disease        0.238451      0.119982       1.000000  0.061376
# Bmi                  0.344797      0.148111       0.061376  1.000000
# HbA1c_level          0.106719      0.081441       0.068140  0.084423
# Blood_glucose_level  0.114317      0.084834       0.070832  0.092543
# Diabetes             0.264927      0.195710       0.170711  0.214932
#
#                      HbA1c_level  Blood_glucose_level  Diabetes
# Age                     0.106719             0.114317  0.264927
# Hypertension            0.081441             0.084834  0.195710
# Heart_disease           0.068140             0.070832  0.170711
# Bmi                     0.084423             0.092543  0.214932
# HbA1c_level             1.000000             0.171615  0.406408
# ...

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df.corr())              
plt.show()

# %%
corr=df.corr()
print(corr)
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
#                           Age  Hypertension  Heart_disease       Bmi  \
# Age                  1.000000      0.257305       0.238451  0.344797
# Hypertension         0.257305      1.000000       0.119982  0.148111
# Heart_disease        0.238451      0.119982       1.000000  0.061376
# Bmi                  0.344797      0.148111       0.061376  1.000000
# HbA1c_level          0.106719      0.081441       0.068140  0.084423
# Blood_glucose_level  0.114317      0.084834       0.070832  0.092543
# Diabetes             0.264927      0.195710       0.170711  0.214932
#
#                      HbA1c_level  Blood_glucose_level  Diabetes
# Age                     0.106719             0.114317  0.264927
# Hypertension            0.081441             0.084834  0.195710
# Heart_disease           0.068140             0.070832  0.170711
# Bmi                     0.084423             0.092543  0.214932
# HbA1c_level             1.000000             0.171615  0.406408
# ...

# %% [markdown]
# # Relation plot between Gender and Age by Heart_disease

# %%
sns.relplot(x="Gender",y="Age",hue="Heart_disease",data=df)   
plt.show()

# %%
sns.pairplot(df, vars=["Age", "Bmi", "Blood_glucose_level"])
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(df,hue ='Smoking_history',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# # logistic regression

# %%
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
# load the dataset
df
print(df)

# retrieve the array of data
data = df.values

# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=1)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# define the model
model = LogisticRegression()


# fit on the training set
model.fit(X_train, y_train)


# predict on test set
yhat = model.predict(X_test)


# evaluate predictions
accuracy = accuracy_score(y_test, yhat)
print('Accuracy: %.2f' % (accuracy*100))

# Create the confusion matrix
cm = confusion_matrix(y_test, yhat)
print("Confusion Matrix:\n", cm)
print("precision:")
precision = precision_score(y_test, yhat)
print(precision*100)
print("Recall:")
recall = recall_score(y_test, yhat)
print(recall*100)
print("F1_Score:")
f1_score = f1_score(y_test, yhat)
print(f1_score*100)
# Out:
#        Gender   Age  Hypertension  Heart_disease Smoking_history    Bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  Blood_glucose_level  Diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd


# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# Create a KNN classifier with the desired number of neighbors (e.g., 7)
knn = KNeighborsClassifier(n_neighbors=7)

# Train the model
knn.fit(X_train, y_train)

# Make predictions on the test data
yhat = knn.predict(X_test)

# Calculate and print the accuracy
accuracy = accuracy_score(y_test, yhat)
print("Accuracy:", accuracy * 100)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, yhat)
print("Confusion Matrix:\n", cm)

print("precision:")
precision = precision_score(y_test, yhat)
print(precision*100)

print("Recall:")
recall = recall_score(y_test, yhat)
print(recall*100)

print("Classification Report :")
print(classification_report(y_test, yhat))
# Out:
# Accuracy: 93.85839465404717
# Confusion Matrix:
#  [[34950    84]
#  [ 2278  1147]]
# precision:
# 93.17627944760358
# Recall:
# 33.48905109489051
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     35034
#            1       0.93      0.33      0.49      3425
#
#     accuracy                           0.94     38459
#    macro avg       0.94      0.67      0.73     38459
# weighted avg       0.94      0.94      0.93     38459

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd

# Assuming you have your data in a DataFrame called 'df'
# Make sure your 'df' has features and a target variable

# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)


# Create a Random Forest classifier with the desired number of estimators (e.g., 10)
RF = RandomForestClassifier(n_estimators=10, n_jobs=-1)

# Train the model
RF.fit(X_train, y_train)

# Make predictions on the test data
yhat = RF.predict(X_test)

# Calculate and print the accuracy
accuracy = accuracy_score(y_test, yhat)
print("Accuracy:", accuracy * 100)

cm = confusion_matrix(y_test, yhat)
print("Confusion Matrix:\n", cm)

print("precision:")
precision = precision_score(y_test, yhat)
print(precision*100)

print("Recall:")
recall = recall_score(y_test, yhat)
print(recall*100)

print("Classification Report :")
print(classification_report(y_test, yhat))
# Out:
# Accuracy: 96.74458514261941
# Confusion Matrix:
#  [[34959    75]
#  [ 1177  2248]]
# precision:
# 96.771416272062
# Recall:
# 65.63503649635037
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     35034
#            1       0.97      0.66      0.78      3425
#
#     accuracy                           0.97     38459
#    macro avg       0.97      0.83      0.88     38459
# weighted avg       0.97      0.97      0.96     38459

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# Assuming you have your data in a DataFrame called 'df'
# Make sure your 'df' has features and a target variable

# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# Create a Decision Tree classifier
dtree = DecisionTreeClassifier()

# Train the model
dtree.fit(X_train, y_train)

# Make predictions on the test data
yhat = dtree.predict(X_test)

# Calculate and print the accuracy
accuracy = accuracy_score(y_test, yhat)
print("Accuracy:", accuracy * 100)

# Calculate and print the confusion matrix
confusion = confusion_matrix(y_test, yhat)
print("Confusion Matrix:")
print(confusion)

print("precision:")
precision = precision_score(y_test, yhat)
print(precision*100)

print("Recall:")
recall = recall_score(y_test, yhat)
print(recall*100)

print("Classification Report :")
print(classification_report(y_test, yhat))
# Out:
# Accuracy: 96.07114069528589
# Confusion Matrix:
# [[34549   485]
#  [ 1026  2399]]
# precision:
# 83.18307905686547
# Recall:
# 70.04379562043795
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     35034
#            1       0.83      0.70      0.76      3425
#
#     accuracy                           0.96     38459
#    macro avg       0.90      0.84      0.87     38459
# weighted avg       0.96      0.96      0.96     38459

# %%
# Support Vector Machine

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)


# Training dataset
svc = SVC().fit(X_train, y_train)
svc.score(X_test, y_test)

# Testing dataset
y_pred = svc.predict(X_test)

# Metrics

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100)

print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 97.07740710886918
# Confusion Matrix:
# [[35034     0]
#  [ 1124  2301]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     35034
#            1       1.00      0.67      0.80      3425
#
#     accuracy                           0.97     38459
#    macro avg       0.98      0.84      0.89     38459
# weighted avg       0.97      0.97      0.97     38459

# %% [markdown]
# <h1 style="color:red;">Create a pie chart to visualize accuracy</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# one-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder.transform(X_test)

# ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# Initialize classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=10),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=7),
    "Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine": SVC(),
}

# Train and evaluate each classifier
accuracy_scores = {}
for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores[name] = accuracy

fig, ax = plt.subplots()
ax.pie(accuracy_scores.values(), labels=accuracy_scores.keys(), autopct='%1.1f%%', startangle=90)

plt.title("Classifier Accuracy Comparison")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# <h1 style="color:Green;"><i>Create a bar chart to visualize confusion Matrix</i></h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# One-hot encode input variables
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
onehot_encoder.fit(X_train)
X_train = onehot_encoder.transform(X_train)
X_test = onehot_encoder .transform(X_test)

# Ordinal encode target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# Initialize classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=10),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=7),
    "Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine": SVC(),
}

# Define a list of colors
colors = ['blue', 'green', 'red', 'purple', 'orange']

# Train and evaluate each classifier
accuracy_scores = {}
fig, ax = plt.subplots()
for i, (name, clf) in enumerate(classifiers.items()):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores[name] = accuracy

    # Set a different color for each bar
    ax.bar(name, accuracy, color=colors[i])

plt.xticks(rotation=45)
plt.ylabel("Accuracy")
plt.title("Classifier Accuracy Comparison")
plt.show()
